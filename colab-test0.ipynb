# %% [markdown]
# <a href="https://colab.research.google.com/github/fjibj/AI/blob/master/colab-test0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !find . -name test0.ipynb
# Out:
# ./drive/My Drive/colab/test0.ipynb

# %%
# %cd ./drive/My Drive/colab
# Out:
# /content/drive/My Drive/colab

# %%
# !git clone https://github.com/wb14123/seq2seq-couplet
# Out:
# Cloning into 'seq2seq-couplet'...
# remote: Enumerating objects: 116, done.
# remote: Total 116 (delta 0), reused 0 (delta 0), pack-reused 116
# Receiving objects: 100% (116/116), 34.18 KiB | 1.37 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd seq2seq-couplet/
# Out:
# /content/drive/My Drive/colab/seq2seq-couplet

# %%
# %cd data/
# Out:
# /content/drive/My Drive/colab/seq2seq-couplet/data

# %%
# %pwd
# Out:
# '/content/drive/My Drive/colab/seq2seq-couplet'

# %%
# !python couplet.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/colab/seq2seq-couplet/model.py:42: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/colab/seq2seq-couplet/model.py:65: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/colab/seq2seq-couplet/seq2seq.py:122: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/colab/seq2seq-couplet/seq2seq.py:12: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# ...

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16077413009515802553, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 7262861632949120141
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 18303348679523564889
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11330115994
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8902557597742994197
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335180 kB
# MemFree:        10293584 kB
# MemAvailable:   12306380 kB
# Buffers:           72472 kB
# Cached:          2083420 kB
# SwapCached:            0 kB
# Active:           842588 kB
# Inactive:        1851156 kB
# Active(anon):     501024 kB
# Inactive(anon):     2376 kB
# Active(file):     341564 kB
# Inactive(file):  1848780 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               484 kB
# Writeback:             0 kB
# AnonPages:        537824 kB
# Mapped:           427284 kB
# Shmem:              2948 kB
# Slab:             165256 kB
# SReclaimable:     127084 kB
# SUnreclaim:        38172 kB
# KernelStack:        4544 kB
# PageTables:         7316 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667588 kB
# Committed_AS:    3430704 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %%
# !nvidia-smi
# Out:
# Fri Nov 22 00:57:47 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.50       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
