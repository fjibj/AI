# %% [markdown]
# <a href="https://colab.research.google.com/github/fjibj/AI/blob/master/15_%E4%BA%BF%E5%8F%82%E6%95%B0_GPT2_%E4%B8%AD%E6%96%87%E9%A2%84%E8%AE%AD%E7%BB%83%E6%A8%A1%E5%9E%8B___1_5B_GPT2_Pretrained_Chinese_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![GitHub stars](https://img.shields.io/github/stars/imcaspar/gpt2-ml?style=social)](https://github.com/imcaspar/gpt2-ml)
# [![GitHub](https://img.shields.io/github/license/imcaspar/gpt2-ml)](https://github.com/imcaspar/gpt2-ml)
# [![Twitter URL](https://img.shields.io/twitter/url?style=social&url=https%3A%2F%2Fgithub.com%2Fimcaspar%2Fgpt2-ml)](https://twitter.com/intent/tweet?text=Wow:&url=https://github.com/imcaspar/gpt2-ml)
# # ⬇ Prerequisites

# %%
# %tensorflow_version 1.x
# !git clone -q https://github.com/imcaspar/gpt2-ml
# %cd /content/gpt2-ml
# !mkdir -p /content/gpt2-ml/models/mega

# !perl 3rd/gdown.pl/gdown.pl https://drive.google.com/open?id=1n_5-tgPpQ1gqbyLPbP1PwiFi2eo7SWw_ models/mega/model.ckpt-100000.data-00000-of-00001
# !wget -q --show-progress https://github.com/imcaspar/gpt2-ml/releases/download/v0.5/model.ckpt-100000.index -P models/mega
# !wget -q --show-progress https://github.com/imcaspar/gpt2-ml/releases/download/v0.5/model.ckpt-100000.meta -P models/mega
# Out:
# /content/gpt2-ml
# models/mega/model.c     [ <=>                ]   3.20K  --.-KB/s    in 0s
# models/mega/model.c     [        <=>         ]   5.20G   159MB/s    in 57s
# model.ckpt-100000.i 100%[===================>]  25.59K  --.-KB/s    in 0.01s
# model.ckpt-100000.m 100%[===================>]  17.62M  81.7MB/s    in 0.2s

# %%
# If gdown.pl failed, please uncomment following code & exec
# !python3 scripts/down_gdrive_file.py -file_id='1n_5-tgPpQ1gqbyLPbP1PwiFi2eo7SWw_' -file_path='models/mega/model.ckpt-100000.data-00000-of-00001'

# %% [markdown]
# # Inference

# %%
# !PYTHONPATH=$(pwd) python3 scripts/interactive_conditional_samples.py -model_config_fn configs/mega.json -model_ckpt models/mega/model.ckpt-100000 -samples 10
# Out:
# WARNING:tensorflow:From /content/gpt2-ml/train/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 🍺Model loaded.
# Input something please:⬇️
# 自己动手写区块链是一件很有趣的事情
# Sample, 1  of  10
# 自己动手写区块链是一件很有趣的事情。可以用基于区块链的货币基金来做区块链。现在货币基金这么多，很多基金做出来的产品品质差强人意，但相信区块链
# 运作过程中你也能遇到一些高手。当然比这个程度的少之又少。对于初入这个行业的人，建议多多研究各家的货币基金产品，不过，作为科研机构，很多技术性
# 的东西都需要大家去攻克，别人的产品，别人的操作方法都可能只是脑袋里想到的。写一个简单的交易平台的标准样例，定一个具体的走势，然后对过去做日内
# 日内等交易记录，当然这里面的内容很多很多，因为我在这个行业也很久了，所以我只是想表达一个模式，就是老师的思路，用于实际的日内实战技巧，希望能
# 帮助到大家。要考虑一下投资人怎么看一个货币基金的行业标准样例，这个可以参考yi##xi##ng##lic##ai的技术分析。区块链在近几年吸
# 引了很多资本的眼球，随之开发了更多的东西，而另一些不一定考虑投资人的认知，很多时候把交易混为一谈，看不太出来区块链是个什么概念，所以需要经常
# 思考和努力。（本文首发于yi##xi##ng##lic##ai官网，全文请点击http://www.yi##xi##ng##lic##ai.
# com/files/c/268.html）所以这篇文章，也只是简单的说一下区块链的基本知识。【区块链概念】技术层面的东西，有一点是相关的，就
# 是很多做这个方向的人都是在证券公司等金融机构工作，从事一些比较底层的工作，所以区块链需要是比较广泛的知识，而不是一般人所知的所谓区块链。区块
# 链可以构建一个全球统一的账本，用这个账本与每一个机构进行沟通，传输账本以后，统一命名为有你账号，钱不离手，不信的话，可以随时写下你的个人信息
# 以及联系方式，成为你的客户。所以简单的理解，区块链是一个规模比较庞大的网络，人和人之间的数据共享和信任，是大数据的基础，也是互联网的一个基础
# 模块。相信很多人知道区块链是一个数据库，比如银行、保险、证券公司等会按照经理给你提供的信息进行一个智能合约，这个产品是基于区块链的，产品本身
# 分多层，每一层都由分布式数据库记录，数据库里也会产生有用的数据，如交易额、交易账户和行为等。所以在网络系统的上下游产业都需要提供这样的数据产
# 品，来确保有用的数据被记录在这些数据中。发现题主提到了高维度，所以，我觉得现在区块链有很多比较有特色的东西，能改变世界的各种新型数据，包括公
# 司的成立、分布式数据库和区块链数据产品，每一个产品都有其独特的背景、特点、挖掘逻辑、参数、数据等，每一种都和数据文化相关，人人皆可从这些产品
# ，获得需要的宝贵经验。看到这里，给大家列一下我个人最近的一些产品，
# Sample, 2  of  10
# 自己动手写区块链是一件很有趣的事情，只要不停不停地说话，不停地调研，不停地交易，无非就是花几天时间完善一个开源的。如果非要说有什么特殊的地方
# ，就是对于监管的要求十分苛刻。区块链作为互联网应用最为容易高精尖的技术之一，在应用产品应用场景上有很多共性，它不仅仅是一种技术，更是一项工具
# ，一个保护开发者的相关模块。区块链（block##cha##in），一种区块链技术，比特币币为代表，作为最新的互联网金融技术，比特币即是区块
# 链的一种表现形式，也是通过区块链进行运算，而我们前面说到的六大监管机制则是比特币运算能力的核心。一、国家标准编号m1##0；nb##76；s
# b##61##2、nb##60##2、nb##62##3、nb##97##0、nb##50##2##b、nb##18##5##c、nb##0
# 9##3##bb、nb##21##6、nb##58##9##a、nb##60##1##e、nb##30##9##b等。二、国际标准编号m1#
# #3，nb##81##3，nb##61##4，nb##59##8##c，nb##65##7等。比特币国际标准编号v1##0，nb##94##
# 8，nb##94##9，nb##40##8，nb##49##5，nb##47##7，nb##89##5，nb##89##6等。三、产品特性目
# 前可以通过测试的技术现在很少，大多数比特币交易平台都是使用区块链进行交易。一是方便二级回购。现在的比特币交易平台都是采用区块链进行运算，而区
# 块链不仅具有很好的匿名性，而且具有比特币交易所需要的十多种全球技术，解决了几乎所有技术问题。使用区块链，它将绑定账户关系变得更加清晰，运算过
# 程更加快速，二次交易更加简单。这样的平台无论是商品的检索，还是收藏，还是整个账户交易过程中的分析挖掘，都可以形成一个巨大的数据库。四、规则的
# 详细，杜预区块链是阿里巴巴集团旗下的互联网技术公司微信平台开发的基于区块链技术开发的一款专用的数据库，内含区块链核心技术，是全球领先、最值得
# 信赖的区块链产品。同时微信对微信支付服务也需要区块链技术支持，独创的数据库技术将于2016年12月15日正式上线。区块链一次测试，终身用区块
# 链核心技术研发的内容直接被应用到互联网行业，不但用来兑换银行卡，而且用来清算，无疑最大程度上保障了用户的安全。区块链是继比特币之后，微信的又
# 一个大跨界技术。区块链一旦具备，比特币理论上可以在全球范围内自由使用，覆盖全球范围内所有领域，其并没有其他的金融技术可比拟。2015年比特币
# 的交易额达7.3亿元，2016年1月，区块链理论上已经突破每10万比特币就有3个区块，世界第一大交易所applepay在中国超过80家线下门
# 店。中国一千多家a股上市公司中，还不包括一家外资。目前已经引入北京、深圳、上海、杭州四地的区块链团队，对区块链进行多次技术应用，对区块链产品
# 的数据分析和传统的运维特性研究领域
# Sample, 3  of  10
# 自己动手写区块链是一件很有趣的事情，区块链技术不仅仅是一门编程语言，甚至它的理论思想还恰恰不是以数学为基础的。首先，通俗地讲，基于区块链的数
# 据结构非常简单，所有这些年来出现过的原始数据结构都是有概率的，那么想解释清楚区块链你就必须了解两个东西：区块链的诞生背景和应用之前，我们知道
# 区块链可以追溯到公元几百年前的古埃及时期。公元几百年前的古埃及开始使用电脑进行记账和交易，随着人们生活水平的提高，数据流对于他们意味着更加珍
# 贵的财富。在几百年的时间内，数据流的演进远远超过了程序所能表示的范围，这种情况最终被阿拉伯文明的数学家杜佛-{杰}-创造出来。阿拉伯文明表示
# 同意阿拉伯文明数学创造的东西是创造，更具有崇高的哲学意义，埃及在数字指印度教神的教导下发展了数学，让广大民众参与了数学研究。约旦创造了比较完
# 善的数字经济体系，比如将二八法则理解为阿拉伯数字法则。埃及文明没有采用阿拉伯数字，但是使用阿拉伯数字作为主数字的数据流也不流行，阿拉伯数字表
# 示多数人的数字，数字与数字组合数字、位数、钩合等各种文字，这种不伦不类的文字表达在现代更加人性化，因为这种文字很容易阅读，还对于除埃及外的几
# 乎所有文明都有所表示。然而，就算是上述这样的理论框架，也很难得到大众的认可，同时相当的数据流可能要经过多层演算，汇编，这种演算很大程度上提高
# 了科学家的工作量。那么要理解阿拉伯数字的诞生也很难，但数学家是无法不知道阿拉伯数字的。进入正题。我们首先要思考的是，区块链的诞生背景。一、人
# 类在更高层次上的数据理论。二、由数据所产生的智能增长。一、区块链的诞生背景和应用之前，我们常常讲数字的理论发展背景，但是数字理论发展的背景基
# 本上是人类第一次认识的数字，因为从数字诞生开始，电脑的普及才到来。那么，电脑的普及总要有支撑这些数字的数据才能够真正产生。那么，在那之前，人
# 类的工作流程已经发生了大幅度的变化，那么，为什么我们使用电脑的时候必须用很多年时间呢，这是因为上一次工业革命后，数字产生的发展趋势一直是越来
# 越先进的，是随着科技的不断发展，科学技术的不断发展，出现越来越多的符号用于代替人类之前用过的符号。我们可以发现，有人工智能加上普及程度较高的
# 信息技术有了很大的提升，效率更高，对于人类来说，技术的不断完善才会提高效率。二、区块链诞生背景从数字诞生到如今，几乎未曾变过。但是，我们一般
# 而言，电脑的效率会相对于信息技术的瓶颈而言会非常大，因为信息的不断更新增加的使用率，但
# Sample, 4  of  10
# 自己动手写区块链是一件很有趣的事情，但现在互联网公司都走上了烧钱路线，也就是烧钱越烧越多，烧钱越烧越贵，烧钱越烧钱的公司不仅只是google
# 和facebook。计算什么的都是一种本科学的内容，你必须花大价钱学个差不多的，因为什么都学不懂，花了无数的金钱才达到那个程度，还是别瞎投了
# ，最后亏的一塌糊涂。项目技术难点都在数据库，就没几个写算法和逻辑思想的，会算一点的都没有，再牛的各大软件公司就更不必说了。中国真正的创新型互
# 联网公司可不多，人家靠的还不是烧钱和技术。区块链今天发布了首个接入商城，其实是个比较新的概念，开发者是英国的la##rryher##ric#
# #k，他已经在本次区块链3.0中做到顶级，英国度假小镇老板，这个项目涉及的是比特币这个概念。小小的接入商城实现了比特币的接入，把原来几千万的
# 人（人类，走进商城了）进行了统一的信任，在继续拿钱。目前大多数公司以re##vo##lv##er为代表，上线将近两个月，产品已经上线了三个月
# 。看起来跟经历过去几年烧钱的互联网的产品其实差不多，有一些公司甚至达到了1个月的年化收益率，这其中有许多创新的公司，但是产品规模能达到1-5
# 亿美金的，能出如此规模的公司就很少了。thej##ui##ce2016forwall##cha##in是2014年份完成，2015年看样子还
# 处于创新阶段，他们只有1个合伙人，难以确定整个公司的运营状况。la##rryher##ric##k不仅在这次接入商城上做的非常完善，他还创建
# 了be##ttervalue联盟，大概的用户和商城类似。公司主营be##ttervalue技术提供商，也是建立be##ttercon##su
# ##merse##c##ur##iti##es合作的前美国非盈利组织，由英国石油公司be##tterco##rp的资助。这个公司主要是追求增
# 加用户粘性，发展更多的数据库，be##ttervalue联盟是这个联盟数据库的合作伙伴。谷歌、苹果、微软、facebook、亚马逊、甲骨文，
# 公司等等全球数百家公司都是这个联盟的合作伙伴。其实，我们大家买了五万多的英镑的，给了三万多的，可以达到这个产品的成交额。二来，市场上还有更多
# 的公司没来挖用户，这需要好长一段时间来积累用户数据。（估计这个公司这个产品应该还没诞生，更多的是无数次的无数据运营经验积累）收不收钱，它不是
# 区块链成立的唯一理由，那区块链是否能走到今天？答案是肯定的，这里最可能的区块链是可以走到今天的，只是在其使用的过程中可能会有一些问题，比如：
# 1.时间周期；2.运维问题；3.货币兑换问题；4.信用问题。区块链如果走到今天，谁也不想那么多人成为区块链的拥簇，到时候，你公司买这种产品的
# 公司当然很多。人类的区块链基本上可以分为两种，一种是简单的c##＋##c＋##er##＋##f，是采用的聚合物型的多层（金属/合金）网络
# Sample, 5  of  10
# 自己动手写区块链是一件很有趣的事情，网上的资料很多，目前还没有成熟的算法，虽然你可以使用googlethink##ing的关键词搜索，比如s
# t##atic：https##sch##ina.block##cha##in.net##sta##tis##tics##bat##y##de
# ##tail##do##c##ument##so##ur##ce##na##v##net##pro##ject##public##s##rc
# ##px##ani##a-h##w-cp##p-wei##ght##de##te##ct##pt##od##st##oc##ode-to-h
# ##w-cp##p，几乎几乎大部分信用卡都支持区块链。（1）->block##cha##in##data##base这个区块链基本上可以实现
# 从客户端发送一个币的密钥给另一个账户，另一个账户受到这个机构的网络加密后，这个网络又能获取这笔卡的密码卡。（2）->t##ren##dord
# er##s专用的一个公用空间。这个区块链通过3个关键字来定义这些独立的账号，分别为privatepay##ment，d##yn##am##i
# cti##cket，share。pay##ment从主机构来源来源，国家和国家公司.（3）->wi##deti##cket##s，t##re
# n##dorder，share##wi##deti##cket的功能，用户根据这个卡的指令来设置不同的应用（比如说拿来做交易）。比如这张卡是
# 一个备选账户，那么就对这个机构设置投了投资。inc##lu##desadi##sco##ver##edin##iti##aldi##rect
# ##oryinthesc##rip##pe##dbank，wearese##llup，outofourca##shre##pl##ace##
# dawall##edcom##put##er，w##hi##chisinfa##ctabout.bythewayofcry##pt##oev
# ##ok##ingfe##es.如果区块链运行正常，那么这个区块链就是你用来制作一个你自己的交易的整合的框架。假如还没有多少人使用block
# ##cha##in，那你也是可以把这里的block##cha##in运用起来。正常情况下，block##cha##in可以被用作为block
# ##cha##in的一部分。简而言之block##cha##in是没有bug的，只有一些程序必须对block##cha##in运行。那么bl
# ock##cha##in实现了什么功能呢？简单来说block##cha##in不用任何东西去做额外的事情，block##cha##in运行简
# 单，无需任何额外的或者其他的东西，只要你的block##cha##in上有block##cha##in就可以了。block##cha##in
# 的一个重要功能就是把一个区块重新整合，因为block##cha##in可以使用block##cha##in的分布式计算，根据block##c
# ha##in来对某个区块进行区块的重新设置。block##cha##in运行了接近一年了，看到此处稍微有些介绍。block##cha##in
# 最初可以看作是block##cha##in的重要功能之一，后来修改了一次后来看到好一些人回答推荐block##cha##in。解释一下blo
# ck##cha##in的基本功能，block##cha##in的根本目的就是成为block##cha##in的fi##ghtcenter，所
# 有block##cha##in公司的开发者都是决定在block##cha##in中成为block##cha##in的fi##ghtcente
# r。（来源：bit##coinr##ift）作者：bit##coinr##ift丨l##w##j##j##zr##ift本文原创，未经许可，
# 禁止转载一篇别人的文章，希望大家多多支持，多提宝贵意见，谢谢大家！block##cha##in是block##cha##in的精髓，也是bl
# ock##cha##in的目标，目前市面上的block##cha##in只有block##cha##in自己做不了。block##cha##
# in也是block##cha##in的核心功能。block##cha##in是一个基于关键字来定义的密码概念，也就是说，block##cha
# ##in不只是为了解码、删除账户，而是为了解码、删除账户。比如重新整合block##cha##in。block##cha##in加密比特币，
# 等同为基于区块
# Sample, 6  of  10
# 自己动手写区块链是一件很有趣的事情，特别是面对各种新兴行业的应用。而且也可以帮助我们搞懂背后的原理，进而有所发挥。公司推荐这个：首先上传公司
# 主页，（链接可以百度到）自己的第一篇文章在这里：区块链接入数据库--------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# ---------------------------------------------
# Sample, 7  of  10
# 自己动手写区块链是一件很有趣的事情，对我来说，最有趣的不是有人把这个东西教给我，而是我相信自己可以写出自己心中的第一个区块链。为了写一个可以
# 运行的区块链，我开始摸索，开始学习。因为找不到很有效的实现方法，所以开始临摹那些网络上的模板。从最初的模仿，到今天的重复。（当然，基础是不会
# 差的，我是从python入门，然后到web开发。。）这个过程其实也很酸甜苦辣。不断的修改，不断的修改，不断的修改，一切都很没趣。（现在想想好
# 可笑，居然还把这玩意儿放进黑名单呢！！！）。然后，我开始google学习。慢慢的，我get到了一个英文版的区块链，就是t##re##llo。
# re##sol##ut##ion。创建一个有价值的项目，还有很多限制，例如https##http##s.t##re##llo.org.cn很
# 有趣。而且很实用。这才是最实用的开发时候的体验。反而有一点，如果自己写的是中文，翻译的时候肯定会有很多问题。但是，试着往里面多掺杂一些外文单
# 词的话，甚至看文档，学习了不少外语单词也是会让你的技术水平有改进的。而且最后，在一个可以使用的合作伙伴帮助下，说起来这个技术很有趣。哈哈。好
# 开心哈哈。简单流程下面是我的实验结果。inre##to##ry结束的过程还算快，因为我还没有开始做代码。哈哈。看看效果，虽然看上去，分区块链
# 的东西还是很复杂的。但是目前大约比之前写一个有价值的区块链好多了。因为扩展性是有保证的。而且每个地方都是一个block，而且是各自不同的块，
# 这样扩展的区块有的一块，有的一块。而且可以实现普通的中文和英文一致。所以看了一些效果，可以参考看看：代码结束后，右边的block是pytho
# n语言的read.h，而左边的block是re##sol##ut##ion.h，所以脚本不使用。那么这也是我能最大化体现分布式编程能力的一个
# 地方。再看看整个代码：p写了一些字符的符号的p块。竖着写了一些数据的p块。用p系统扩展可以在本地实现中文。中文设置进入模板的p块。写了一些下
# 面的东西：结束：）打开微信联系人选择一个可以用的页面，点击右边的功能，会看到底下的地址栏。就能将z轴放在地址栏上，竖着回车等。z轴有一个功能
# ，就是可以把地址栏设置为填充的模型。你不需要额外的操作，反正按照z轴标签的栏位关注设置一个就可以。功能在微信以上的代码都集成在一个模板里：z
# ##ql##ad##mo##b.p##l##ht.mk##l##z##r，上面会包含一些操作：用z##ql##ad中比较基本的h##g##z
# 字符的转换。所有参数都在z##ql##ad##zy##l##z##r.mk##l##z##r.p##l##z##r.p##l##z##r.p
# ##l##z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l#
# #z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l##z##r.p##l##z##
# r.p##l
# Sample, 8  of  10
# 自己动手写区块链是一件很有趣的事情，过去一直不太明白为什么会有程序员自己写区块链，现在看来，区块链其实是一个很好的数据挖掘工具，任何大型数据
# 的处理都可以用到它。区块链的工作原理其实是非常简单的，涉及数据挖掘和数据分析。前端区块链开发在二十世纪八十年代诞生后，就成为了历史数据挖掘领
# 域中继hadoop和sql之后的下一个风口。在1995年的时候，随着引擎的发展，hadoop的快速普及，java来补足缺口，c和python
# 则作为过渡的选择。其他语言的大规模部署与网络的发展，使得编程语言的变革为数据挖掘领域的新增长点。这种新方法产生了一些经典的工具，当前较大的有
# ibmwin##cel##l、open##int##ell##ig##ence、st##ru##ts、active##x、spark、pyt
# hon等等。这些工具在其时已经被人们所普遍接受，如今的微型机，开发工具的数量已经很多，工具的风格也有所区别。尽管在开发数据挖掘的时候，曾经有
# 过一些内部分工，但是大规模出现的都是非核心的分类数据挖掘工具。在游戏和工具程序设计领域，还没有一种工具可以完美解决这个问题。总的来讲，在技术
# 实现层面上，将任何程序拆分成多个工具，是前端数据挖掘、大规模机器人的软件开发、大规模的ai软件开发与操作的工作，也包括数据处理、数据管理、大
# 规模网络处理和网络应用等等工作。这些工具就是随着系统资源的不断挤压，而涌现出来的一些新的工具，所以经常被叫做大数据。在前端领域，经常也包括h
# ttp与session资源管理。但是近年来已经出现的sql语句的出现，让任何比较精致的工具变得易于掌握，也正是这种工具诞生，如今被大众所广泛
# 使用，这样的工具对于入门级的数据挖掘工作，已经足够的简单。目前来看，前端工程师中最为人熟知的就是sql，sql相对于传统的sql语句，是更为
# 多采的语言，包括了发送通知、预览、返回、修改和状态修复等诸多概念。对于sql的发展与应用，也是被广泛的采用，举例来说，我们在网页上经常可以看
# 到日期的日期，关于标签词的标记，正如这些标签显示的意思一样，日期的标记经常是百分百正确。但是对于一些大型数据挖掘、大规模机器人的工作，用到的
# 是sql语句，因为还要实现更多的处理，后端的数据挖掘、大规模机器人的软件开发，会是一个全新的世界。更有专家提出一个新的概念：语言+技术+后端
# +数据分析。因为比较高层的系统与开发，数据挖掘、大规模机器人挖掘、大型软件开发，在中国还远远没有形成一个系统，企业级的是还没有形成一个系统。
# 这种状况在业界内也有，参与的项目没有形成系统，就如卖矿泉水的农民也没有操作上的难度，其实这种状况是一种正常的市场。而web为服务器的环境主要
# Sample, 9  of  10
# 自己动手写区块链是一件很有趣的事情。你至少需要知道怎么写，算法什么的无非就是国外那一套而已。就像把中文字母的冠词那一套搬上来一样。如果不想接
# 触中文，又喜欢写英文，就开发一些小工具，比如：bit##coin（美国的比特币平台）do##tc##lo##ud（外国的比特币交易平台）au
# ##th##coin（国外的比特币交易平台）swift##yo##ft##ime（比特币支付平台）。软件要求简单，可以实现基本的事情。需要的
# 功能就是这些，实现目标就可以了。等各位功能实现完之后我会有个更好的答案。另外和中国区块链技术迅速发展及世界领先相比，中国区块链技术落后美国2
# 0年。根据我们编写的区块链官方引擎http##mon##ey.bit##coin.org，里面含有超过5000万个改进功能，每个功能十个，四
# 十个，大约相当于三个程序。没有怎么编写就四处跑的，中国区块链的开发速度非常慢，而且根本没法去开发。其中一些功能，比如区块链数据交换、通讯、交
# 易规则、数据模型都有明显提升。最明显的是流动性，其实用语言就可以完成。两年前，我们就可以编写成mon##ey.docker这样的一个原型，不
# 需要任何开发工具，效率高，内存超级大，只有一台电脑就可以完成。这样，用户在云端直接登录，并且他的账号还可以在于账号的一致性，记录你的行为，发
# 现你的问题，然后直接修改你的账号密码，然后将你的账号转账。也就是说，用户的一些账号将不需要编程，无需开发环境，可以直接在两个月内编程，无需更
# 新。后来，区块链的概念越来越流行，比如如果一些客户给一个公司指定的额度，只需指定一个部门的人员进行编程，然后运行到他所在的商品或服务上来。那
# 么，整个模型就确定下来了。比如这个第五代区块链，就是其中一个部门编程。比如mon##ey.pe##rl、pe##rlmicro##wa##v
# e、的github账号、mon##ey.co的版本号，里面都有账号、权限。接下来中国区块链就遇到了一个比较大的问题，比如节点的分布，使用这一
# 块商品的一些服务部门在各个部门，比如开发商，监管部门等。以mon##ey.为例，他是一个现货交易平台。比如，这个他做了这件商品的全部流程，里
# 面分成了创新部、创新中心、打交道的比较，主流部分才几十个人，大家的关系非常好，经常一起开发和运行这个应用。后来他们开发的服务的中心在各个部门
# 这块是打交道的，所以这一块是扁平化的。如果像单位，商品的需求也都汇集在一起，你就像联通、移动，或者运营商，市面上各个部门都能通过一个新的服务
# ，去满足和配合。所以当客户指定的是这个部门的人员，但他的的账号、密码、控制权限不是一个现代信息系统的常用技术部门，还是开发部门的时候，就会出
# 现一种乌龙的情况。随后，区块链的应
# Sample, 10  of  10
# 自己动手写区块链是一件很有趣的事情。因为它和分布式账本的关系类似于套现，但又不完全相同。要了解区块链，首先要了解区块链概念及其基本原理。一区
# 块链能产生什么？假设一个矿坑有10个矿块，每个矿块分别有a元b元c元d元和e元，那么每个矿块的总值是a元，c元和d元的总值依次为：c元a元c
# 元d元和e元。一个矿坑有多少矿块，取决于一堆相同的矿块在同一时刻的分布。这堆矿块的总值又反映了矿坑之间的距离（此处应加黑）。由于各矿点的距离
# 相等，每个矿点对应的矿块的比值经过验证可以被确定，而每个矿点之间的边界是相等的。只要将每个矿点与这堆矿块的边界的距离确定后，那么最终的边界就
# 成为了矿坑的本体。大家在学习区块链的时候，其最基本的概念便是要了解，如何确定每一个矿块的分布。区块链的初衷是将数据在网络上保存，并为每一个数
# 据块创建一个数据库来获取这堆数据。随着区块链技术的发展，越来越多的矿点开始探索将之建立数据库，以便更好地运行区块链，为各自的数据提供更加强大
# 的数据库支撑。如何利用区块链来获取原始数据？下面，就我个人而言，我不建议大家使用第三方数据库（数据库常常是以网络形式存在），因为这里涉及网络
# 。最终，要解决的是在哪些数据不可能被收集的情况下，如何使用一种新的数据库创建一个原始数据库。只要目前的所有数据（地点，地理位置）都被验证了，
# 我们就能够构建一个原始数据库了。创建原始数据库的方法有两种：一是开发人员直接构建一个原始数据库，二是将数据聚合在一个区块中。如何最小化运行程
# 序的损耗：对于第一种方法，要求你无需重复建立一堆证明没有问题的证明（如su##b##lo##c那个部分），因为有一堆数据。对于第二种方法，它
# 便需要对网络进行计算（网络中常见的计算方法有s##vm、dl##ap、st##r和ra##nge。这里主要讨论后一种，因为他们都是由一堆数据
# 串联起来的）。针对这一点，我的看法是，把同一时刻的数据封装在一个区块中，便于完整调查，同时也给软件提供了冗余检查的空间。要找一堆好的数据，编
# 程是最有效的办法之一。如何简单地构建区块链？如何最低成本构建一个区块链？比如一堆矿物（如铁矿石）；一个区块中有多少块矿石（如铜矿石），有多少
# 块矿石（如铁矿石），有多少块矿石（如钴矿），这些都能找到。如何简单组建区块链？一种最简单的方法是联合创建一个原始的区块链，它便于记录下一个矿
# 点的所有矿块。然后假设每一个矿点的分布都已经确定，再从该矿点开始重新建立新的矿点并且使之关联到同一块。需要注意的是，比如在form##ula
# _1区块
